# %%
import numpy as np
import pandas as pd

import os
from dateutil import parser
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta

# %%
file_name = 'employee_data.csv'

# %%
df = pd.read_csv(file_name)

# %%
df.dob = pd.to_datetime(df['dob'])

# %%
df.head()
# Out:
#    emp_id                  emp_name        dob gender marital_status  \
# 0   10026       Adinolfi, Wilson  K 1983-07-10     M          Single
# 1   10084  Ait Sidi, Karthikeyan    1975-05-05     M         Married
# 2   10196         Akinkuolie, Sarah 1988-09-19      F        Married
# 3   10088              Alagbe,Trina 1988-09-27      F        Married
# 4   10069          Anderson, Carol  1989-09-08      F       Divorced
#
#           department                  position       employment_status  \
# 0  Production          Production Technician I                  Active
# 1              IT/IS                   Sr. DBA  Voluntarily Terminated
# 2  Production         Production Technician II  Voluntarily Terminated
# 3  Production          Production Technician I                  Active
# 4  Production          Production Technician I  Voluntarily Terminated
#
#      manager_name performance_score  absences  salary
# 0  Michael Albert           Exceeds         1   62506
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   emp_id             311 non-null    int64
#  1   emp_name           311 non-null    object
#  2   dob                311 non-null    datetime64[ns]
#  3   gender             311 non-null    object
#  4   marital_status     311 non-null    object
#  5   department         311 non-null    object
#  6   position           311 non-null    object
#  7   employment_status  311 non-null    object
#  8   manager_name       311 non-null    object
#  9   performance_score  311 non-null    object
#  10  absences           311 non-null    int64
#  11  salary             311 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 29.3+ KB

# %%
sum(df.dob > datetime.now())
# Out:
# 38

# %%
for col in ["marital_status", "department", "position", "employment_status", "performance_score"]:
    print(col, '::', sum(df[col].str.len() > 20 ))
# Out:
# marital_status :: 0
# department :: 0
# position :: 206
# employment_status :: 88
# performance_score :: 0

# %%
df['dob'] = df.dob.apply(lambda x: x - timedelta(days=36525) if x > datetime.now() else x)

# %%
arr = df.dob.apply(lambda x: (x - datetime.now()) > timedelta(days=36525))
arr.sum()
# Out:
# 0

# %%
df.to_dict('records')
# Out:
# [{'emp_id': 10026,
#   'emp_name': 'Adinolfi, Wilson  K',
#   'dob': Timestamp('1983-07-10 00:00:00'),
#   'gender': 'M ',
#   'marital_status': 'Single',
#   'department': 'Production       ',
#   'position': 'Production Technician I',
#   'employment_status': 'Active',
#   'manager_name': 'Michael Albert',
#   'performance_score': 'Exceeds',
#   'absences': 1,
#   'salary': 62506},
#  {'emp_id': 10084,
#   'emp_name': 'Ait Sidi, Karthikeyan   ',
#   'dob': Timestamp('1975-05-05 00:00:00'),
#   'gender': 'M ',
#   'marital_status': 'Married',
#   'department': 'IT/IS',
#   'position': 'Sr. DBA',
#   'employment_status': 'Voluntarily Terminated',
#   'manager_name': 'Simon Roup',
#   'performance_score': 'Fully Meets',
#   'absences': 17,
#   'salary': 104437},
#  {'emp_id': 10196,
#   'emp_name': 'Akinkuolie, Sarah',
#   'dob': Timestamp('1988-09-19 00:00:00'),
#   'gender': 'F',
#   'marital_status': 'Married',
#   'department': 'Production       ',
# ...

# %%
df.to_csv('emp_data.csv', index=False)
